# %%
import numpy as np
import pandas as pd

# %%
d = {
    'col1': np.arange(10),
    'col2': np.arange(10),
}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#    col1  col2
# 0     0     0
# 1     1     1
# 2     2     2
# 3     3     3
# 4     4     4
# 5     5     5
# 6     6     6
# 7     7     7
# 8     8     8
# 9     9     9

# %%
df.query('col1 == 4')
# Out:
#    col1  col2
# 4     4     4

# %%
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'

# %%
fig, axes = plt.subplots(ncols=df.shape[1], figsize=(16,5))
for col, ax in zip(df.columns, axes):
    ax.plot(...)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fa995cd68d0>,
#   <matplotlib.lines.Line2D at 0x7fa995cfbd90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fa995cd69d0>,
#   <matplotlib.lines.Line2D at 0x7fa995d007d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fa995cd6a10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fa995d00d10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa995cfbe10>],
#  'means': []}

# %%
fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(16,5))
